# %%
from pylab import *
import pandas as pd
# %matplotlib inline

# %%
tb=pd.read_csv("Data_S1.cdt",sep="\t",header=None,skiprows=7)

# %%
imshow(tb.iloc[:,7:].values,aspect="auto",cmap="bwr")
colorbar()

# %%
tb.iloc[:,7:].values.max()
# Out:
# 6.1124539375

# %%
len(tb)
# Out:
# 3017
